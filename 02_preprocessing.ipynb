# %%
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: textblob in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: nltk in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (3.9.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: spacy in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (3.8.7)
# Requirement already satisfied: bs4 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (0.0.2)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: ipython in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (9.6.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (3.10.7)
# Requirement already satisfied: click in ./.venv/lib/python3.13/site-packages (from nltk->-r requirements.txt (line 2)) (8.3.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.13/site-packages (from nltk->-r requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.13/site-packages (from nltk->-r requirements.txt (line 2)) (2025.11.3)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (from nltk->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in ./.venv/lib/python3.13/site-packages (from scipy->-r requirements.txt (line 3)) (2.3.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (2.12.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.venv/lib/python3.13/site-packages (from spacy->-r requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in ./.venv/lib/python3.13/site-packages (from langcodes<4.0.0,>=3.2.0->spacy->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in ./.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 5)) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in ./.venv/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.venv/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy->-r requirements.txt (line 5)) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy->-r requirements.txt (line 5)) (14.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./.venv/lib/python3.13/site-packages (from weasel<0.5.0,>=0.1.0->spacy->-r requirements.txt (line 5)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./.venv/lib/python3.13/site-packages (from weasel<0.5.0,>=0.1.0->spacy->-r requirements.txt (line 5)) (7.4.3)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.13/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.13/site-packages (from bs4->-r requirements.txt (line 6)) (4.14.2)
# Requirement already satisfied: notebook in ./.venv/lib/python3.13/site-packages (from jupyter->-r requirements.txt (line 7)) (7.4.7)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.13/site-packages (from jupyter->-r requirements.txt (line 7)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.13/site-packages (from jupyter->-r requirements.txt (line 7)) (7.16.6)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.13/site-packages (from jupyter->-r requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.13/site-packages (from jupyter->-r requirements.txt (line 7)) (8.1.8)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.13/site-packages (from jupyter->-r requirements.txt (line 7)) (4.4.10)
# Requirement already satisfied: decorator in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.13/site-packages (from ipython->-r requirements.txt (line 8)) (5.14.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r requirements.txt (line 8)) (0.2.14)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 8)) (0.8.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./.venv/lib/python3.13/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.13/site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 6)) (2.8)
# Requirement already satisfied: appnope>=0.1.2 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (5.9.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.13/site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.13/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 7)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.13/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 7)) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2->spacy->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.13/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.13/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.13/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.13/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 7)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.venv/lib/python3.13/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 7)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.13/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 7)) (0.2.4)
# Requirement already satisfied: anyio in ./.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (4.11.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (4.25.1)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.28.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (25.10.0)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 7)) (6.3.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.13/site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.13/site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.13/site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.13/site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.13/site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in ./.venv/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (2.23)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: tzdata in ./.venv/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.13/site-packages (from stack_data->ipython->-r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.13/site-packages (from stack_data->ipython->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.13/site-packages (from stack_data->ipython->-r requirements.txt (line 8)) (0.2.3)

# %%
from textblob import TextBlob
from string import punctuation, ascii_lowercase, ascii_letters, ascii_uppercase
from nltk.stem import PorterStemmer, SnowballStemmer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from textblob import TextBlob
#       2 from string import punctuation, ascii_lowercase, ascii_letters, ascii_uppercase
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/textblob/__init__.py:1
# ----> 1 from .blob import Blobber, Sentence, TextBlob, Word, WordList
#       3 __all__ = [
#       4     "TextBlob",
#       5     "Word",
#    (...)      8     "WordList",
#       9 ]
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/textblob/blob.py:27
#      24 import sys
#      25 from collections import defaultdict
# ---> 27 import nltk
#      29 from textblob.base import (
#      30     BaseNPExtractor,
#      31     BaseParser,
#    (...)     34     BaseTokenizer,
#      35 )
#      36 from textblob.decorators import cached_property, requires_nltk_corpus
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/nltk/__init__.py:180
#     177 else:
#     178     from nltk import cluster
# --> 180 from nltk.downloader import download, download_shell
#     182 # Check if tkinter exists without importing it to avoid crashes after
#     183 # forks on macOS. Only nltk.app, nltk.draw, and demo modules should
#     184 # have top-level tkinter imports. See #2949 for more details.
#     185 if importlib.util.find_spec("tkinter"):
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/nltk/downloader.py:2528
#    2518             pass
#    2521 ######################################################################
#    2522 # Main:
#    2523 ######################################################################
#    (...)   2526
#    2527 # Aliases
# -> 2528 _downloader = Downloader()
#    2529 download = _downloader.download
#    2532 def download_shell():
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/nltk/downloader.py:503, in Downloader.__init__(self, server_index_url, download_dir)
#     501 # decide where we're going to save things to.
#     502 if self._download_dir is None:
# --> 503     self._download_dir = self.default_download_dir()
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/nltk/downloader.py:1056, in Downloader.default_download_dir(self)
#    1052     return
#    1054 # Check if we have sufficient permissions to install in a
#    1055 # variety of system-wide locations.
# -> 1056 for nltkdir in nltk.data.path:
#    1057     if os.path.exists(nltkdir) and nltk.internals.is_writable(nltkdir):
#    1058         return nltkdir
#
# AttributeError: partially initialized module 'nltk' from '/Users/lindapotakowskyj/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/nltk/__init__.py' has no attribute 'data' (most likely due to a circular import)

# %%
with open("output/quote_10.txt", "r", encoding="utf-8") as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 with open("output/quote_10.txt", "r", encoding="utf-8") as file:
#       2     content = file.read()
#
# File ~/Documents/GitHub/datascienceapplicaionts_media/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/quote_10.txt'

# %% [markdown]
# content = conent.lower

# %%
new_content = ""
for char in content:
    if char not in punctuation + +:
        new_content = new_content + char

content = new_content

# %%
# !python3 -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/lindapotakowskyj/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/lindapotakowskyj/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/lindapotakowskyj/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/lindapotakowskyj/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/lindapotakowskyj/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/lindapotakowskyj/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.
